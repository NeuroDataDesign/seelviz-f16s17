# %%
import networkx as nx

# %%
aut = nx.read_graphml("Aut1367.graphml")

# %%
out = nx.maximal_matching(aut)

# %%
out
# Out:
# {('s2824', 's2916'),
#  ('s3348', 's3104'),
#  ('s2183', 's2253'),
#  ('s2650', 's2463'),
#  ('s1437', 's1507'),
#  ('s4524', 's4609'),
#  ('s1252', 's997'),
#  ('s1728', 's1765'),
#  ('s440', 's504'),
#  ('s1848', 's1672'),
#  ('s605', 's551'),
#  ('s1682', 's1744'),
#  ('s3192', 's3166'),
#  ('s1532', 's1253'),
#  ('s4218', 's3994'),
#  ('s1356', 's1497'),
#  ('s1660', 's1659'),
#  ('s183', 's195'),
#  ('s42', 's66'),
#  ('s1073', 's1094'),
#  ('s2747', 's2796'),
#  ('s581', 's402'),
#  ('s2296', 's2607'),
#  ('s3132', 's3044'),
#  ('s3123', 's3275'),
#  ('s2386', 's2333'),
#  ('s2003', 's2070'),
#  ('s1297', 's1388'),
#  ('s463', 's390'),
#  ('s1084', 's1043'),
#  ('s738', 's627'),
#  ('s4101', 's3888'),
#  ('s3855', 's3981'),
#  ('s1923', 's1969'),
#  ('s380', 's396'),
#  ('s1054', 's930'),
#  ('s310', 's369'),
#  ('s3600', 's3685'),
#  ('s3740', 's3739'),
#  ('s2065', 's2151'),
#  ('s288', 's344'),
#  ('s2713', 's2900'),
#  ('s658', 's750'),
#  ('s4544', 's4332'),
# ...
