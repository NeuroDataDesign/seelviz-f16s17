# %%
import igraph as ig

import json
import urllib2

data = []
req = urllib2.Request("https://raw.githubusercontent.com/Upward-Spiral-Science/seelviz/gh-pages/graphfiles/Fear199.json")
opener = urllib2.build_opener()
f = opener.open(req)
data = json.loads(f.read())

print data.keys()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-1e50f06e22fd> in <module>()
#       8 opener = urllib2.build_opener()
#       9 f = opener.open(req)
# ---> 10 data = json.loads(f.read())
#      11
#      12 print data.keys()
#
# /home/albertlee/miniconda2/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /home/albertlee/miniconda2/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# ...
