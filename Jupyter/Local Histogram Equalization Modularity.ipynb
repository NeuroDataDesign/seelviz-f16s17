# %%
# %matplotlib inline
import os
os.chdir("/Users/albert/ndreg")

# %%
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import cv2
import ndreg as nr
import matplotlib as mp
import SimpleITK as sitk

# %%
c174 = nr.imgRead('../Cocaine174.img')
nr.imgShow(c174)

# %%
nr.imgShow(inImg, vmax=500)

# %%
c174 = nb.load('../Cocaine174.img')
#originalimgArray = sitk.GetArrayFromImage(c174)
#shape = originalimgArray.shape
c174_data = c174.get_data()
c174 = c174_data[:,:,:,0]

shape = c174.shape
x_value = shape[0]
y_value = shape[1]
z_value = shape[2]

imgflat = c174.reshape(-1)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)

localimgflat = cl1
new_imgArray = localimgflat.reshape(x_value, y_value, z_value)
newc174 = sitk.GetImageFromArray(new_imgArray)

# %%
nr.imgShow(newc174)

# %%
nr.imgShow(newimg)

# %%
nr.imgShow(newc174, vmax=500)

# %%
imgArray = sitk.GetArrayFromImage(inImg)
shape = imgArray.shape

locations = c1
size = locations.shape
print size
# Out:
# [[   4.    0.  912.]
#  [   4.    0.  944.]
#  [   4.  654.  928.]
#  ...,
#  [ 775.  650.  514.]
#  [ 775.  650.  517.]
#  [ 775.  650.  518.]]
# (35210, 3)

# %%
totalTile = size[0]*size[1]*size[2]
adjustedTile = 8/totaltile
print adjustedTile
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-cd1895046d4f> in <module>()
# ----> 1 totalTile = size[0]*size[1]*size[2]
#       2 adjustedTile = 8/totaltile
#       3 print adjustedTile
#
# IndexError: tuple index out of range

# %%
inImg = nr.imgRead('in.img')
nr.imgShow(inImg)

# %%
nr.imgShow(inImg, vmax=500)

# %%
imgArray = sitk.GetArrayFromImage(inImg)
shape = imgArray.shape
x_value = shape[0]
y_value = shape[1]
z_value = shape[2]

imgflat = imgArray.reshape(-1)

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)

# %%
localimgflat = cl1

# %%
new_imgArray = localimgflat.reshape(x_value, y_value, z_value)
newimg = sitk.GetImageFromArray(new_imgArray)

# %%
nr.imgShow(newimg)

# %%
nr.imgShow(newimg, vmax=500)

# %%
size = shape

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)
