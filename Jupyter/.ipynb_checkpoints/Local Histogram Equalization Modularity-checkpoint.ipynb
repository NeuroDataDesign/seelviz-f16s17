# %%
# %matplotlib inline
import os
os.chdir("/Users/albert/ndreg")

# %%
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import cv2
import ndreg as nr
import matplotlib as mp
import SimpleITK as sitk

# %%
c174 = nr.imgRead('../Cocaine174.img')
nr.imgShow(c174)

# %%
nr.imgShow(inImg, vmax=500)

# %%
c174 = nb.load('../Cocaine174.img')
#originalimgArray = sitk.GetArrayFromImage(c174)
#shape = originalimgArray.shape
c174_data = c174.get_data()
c174 = c174_data[:,:,:,0]

shape = c174.shape
x_value = shape[0]
y_value = shape[1]
z_value = shape[2]

imgflat = c174.reshape(-1)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)

localimgflat = cl1
new_imgArray = localimgflat.reshape(x_value, y_value, z_value)
newc174 = sitk.GetImageFromArray(new_imgArray)

# %%
nr.imgShow(newc174)

# %%
nr.imgShow(newimg)

# %%
nr.imgShow(newc174, vmax=500)

# %%
size = c174.shape
print size
# Out:
# (815, 655, 1407)

# %%
totalTile = size[0]*size[1]*size[2]
print totalTile
scaleValue = totalTile/8
print scaleValue
adjustedTile = float(8/totalTile)
print adjustedTile
# Out:
# 751091775
# 93886471
# 0.0

# %%
inImg = nr.imgRead('in.img')
nr.imgShow(inImg)

# %%
nr.imgShow(inImg, vmax=500)

# %%
imgArray = sitk.GetArrayFromImage(inImg)
shape = imgArray.shape
x_value = shape[0]
y_value = shape[1]
z_value = shape[2]

imgflat = imgArray.reshape(-1)

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)

# %%
localimgflat = cl1

new_imgArray = localimgflat.reshape(x_value, y_value, z_value)
newimg = sitk.GetImageFromArray(new_imgArray)

# %%
nr.imgShow(newimg)

# %%
nr.imgShow(newimg, vmax=500)

# %%
aligned_brain = nb.load('in.img')
aligned_data = aligned_brain.get_data()
aligned_brain = aligned_data[:,:,:]

size = aligned_brain.shape

totalTile = size[0]*size[1]*size[2]
print totalTile
scaleValue = totalTile/8
print scaleValue
adjustedTile = float(8/totalTile)
print adjustedTile
# Out:
# 77045760
# 9630720
# 0.0

# %%
'''
751091775
93886471
0.0
'''

print float(totalTile/751091775.0)
clahe_scale = 8*0.102578356686
print clahe_scale
# Out:
# 0.102578356686
# 0.820626853488

# %%
inImg = nr.imgRead('in.img')
imgArray = sitk.GetArrayFromImage(inImg)
shape = imgArray.shape
x_value = shape[0]
y_value = shape[1]
z_value = shape[2]

imgflat = imgArray.reshape(-1)

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(clahe_scale,clahe_scale))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-775259788dd0> in <module>()
# ----> 1 clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(clahe_scale,clahe_scale))
#       2 img_grey = np.array(imgflat * 255, dtype = np.uint8)
#       3 cl1 = clahe.apply(img_grey)
#
# TypeError: integer argument expected, got float

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(1,1))
img_grey = np.array(imgflat * 255, dtype = np.uint8)
cl1 = clahe.apply(img_grey)

# %%
localimgflat = cl1
new_imgArray = localimgflat.reshape(x_value, y_value, z_value)
newimg = sitk.GetImageFromArray(new_imgArray)

# %%
nr.imgShow(newimg)

# %%
nr.imgShow(newimg, vmax=500)

# %%
custom_data = nb.load('in.img')
custom_data = custom_data.get_data()[:,:,:]

# %%
def imgToPoints(self, threshold=0.1, sample=0.5, optimize=True):
        """Method to extract points data from the img file."""
        if not 0 <= threshold < 1:
            raise ValueError("Threshold should be within [0,1).")
        if not 0 < sample <= 1:
            raise ValueError("Sample rate should be within (0,1].")
        if self._img is None:
            raise ValueError("Img haven't loaded, please call loadImg() first.")

        total = self._shape[0]*self._shape[1]*self._shape[2]
        print("Coverting to points...")
        print("(This will take couple minutes)")
        # threshold
        filt = self._img > threshold * self._max
        x, y, z = np.where(filt)
        v = self._img[filt]
        v = np.int16(255*(np.float32(v)/np.float32(self._max)))
        l = v.shape
        print("Above threshold=%d"%(l))
        # sample
        if sample < 1.0:
            filt = np.random.random(size=l) < sample
            x = x[filt]
            y = y[filt]
            z = z[filt]
            v = v[filt]
        self._points = np.vstack([x,y,z,v])
        self._points = np.transpose(self._points)
        print("Samples=%d"%(self._points.shape[0]))
        print("Finished")
        return self
    
def loadEqImg(self, path = 'in.img', info=False):
        img = nb.load(path)
        if info:
            print(img)
        self._img = img.get_data()
        self._shape = self._img.shape
        self._max = np.max(self._img)
        print("Image Loaded: %s"%(path))
        return self

# %%
in_data_aligned = loadEqImg(custom_data)
plotly_data_aligned = imgToPoints(in_data_aligned, threshold=0.3, sample=0.14)
# Out:
# Image Loaded: in.img
# Coverting to points...
# (This will take couple minutes)
# Above threshold=280084
# Samples=39302
# Finished

# %%
np.savetxt('../innew.csv', plotly_data_aligned._points, fmt='%d',delimiter=',')

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
from plotly.graph_objs import *
from plotly import tools
import plotly
plotly.offline.init_notebook_mode()
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.16.2
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
print plotly_data_aligned._points
print plotly_data_aligned._points.shape
# Out:
# [[ 54 162 258  92]
#  [ 55 163 234  77]
#  [ 55 163 254  80]
#  ...,
#  [409 162 253  79]
#  [411 158 262 105]
#  [411 159 264  76]]
# (39302, 4)

# %%
inImg = nr.imgRead('in.img')
imgArray = sitk.GetArrayFromImage(inImg)
shape = imgArray.shape
x_value = shape[0]
y_value = shape[1]
z_value = shape[2]

plotly_data_aligned_flat = plotly_data_aligned._points.reshape(-1)
new_plotly_data = plotly_data_aligned_flat.reshape(x_value, y_value, z_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-182c6b0e1dde> in <module>()
#       7
#       8 plotly_data_aligned_flat = plotly_data_aligned._points.reshape(-1)
# ----> 9 new_plotly_data = plotly_data_aligned_flat.reshape(x_value, y_value, z_value)
#
# ValueError: total size of new array must be unchanged

# %%
trace1 = Scatter3d(
    x = new_plotly_data[0], 
    y = new_plotly_data[1],
    z = new_plotly_data[2],
    mode='markers',
    marker=dict(
        size=1.2,
        color='purple',                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.15
    )
)

data = [trace1]
layout = Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
