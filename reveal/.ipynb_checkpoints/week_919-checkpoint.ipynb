# %%
import os
from IPython.core.display import Image, display
from IPython.display import Image

# %%
imageID1 = 'Aut1360localeq.5000.'
imageID2 = 'Aut1367localeq.5000.'
imageID3 = 'Aut1374localeq.5000.'
imageID4 = 'AutAlocaleq.5000.'
imageID5 = 'Cocaine174localeq.5000.'
imageID6 = 'Cocaine175localeq.5000.'
imageID7 = 'Cocaine178localeq.5000.'
imageID8 = 'Control181localeq.5000.'
imageID9 = 'Control182localeq.5000.'
imageID10 = 'Control189localeq.5000.'
imageID11 = 'Control239localeq.5000.'
imageID12 = 'Control258localeq.5000.'
imageID13 = 'Fear187localeq.5000.'
imageID14 = 'Fear197localeq.5000.'
imageID15 = 'Fear199localeq.5000.'
imageID15 = 'Fear200localeq.5000.'

# %%
display(Image(filename= imageID1 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID2 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID3 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID4 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID5 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID6 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID7 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID8 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID9 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID10 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID11 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID12 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID13 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID14 + 'graphmldegreesequence' +'.png'))
display(Image(filename= imageID15 + 'graphmldegreesequence' +'.png'))

# %%
display(Image(filename= imageID1 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID2 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID3 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID4 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID5 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID6 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID7 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID8 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID9 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID10 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID11 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID12 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID13 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID14 + 'graphmlclusteringcoefficients' +'.png'))
display(Image(filename= imageID15 + 'graphmlclusteringcoefficients' +'.png'))

# %%
display(Image(filename= imageID1 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID2 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID3 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID4 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID5 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID6 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID7 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID8 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID9 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID10 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID11 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID12 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID13 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID14 + 'graphmlscanstatistic' +'.png'))
display(Image(filename= imageID15 + 'graphmlscanstatistic' +'.png'))
