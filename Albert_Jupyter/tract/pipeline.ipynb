# %%
from PIL import Image
import numpy as np
import scipy.misc
import nibabel as nb
from ndreg import *

# %%
import os

# %%
# !ls -lh Aut1367.nii
# Out:
# -rw-r--r-- 1 root root 1.3G Mar  6 06:27 Aut1367.nii

# %%
inImg = imgRead('Aut1367.nii')
imgShow(inImg, vmax = 500)

# %%
type(inImg)
print np.asarray(inImg).shape

# %%
inArray = sitk.GetArrayFromImage(inImg)

# %%
print inArray.shape
print type(inArray)
# Out:
# (1225, 912, 595)
# <type 'numpy.ndarray'>

# %%
plane = 0;
for plane in (0,1,2,3):
    output = inArray[plane]
    ## Save as TIFF
    scipy.misc.toimage(output).save('sample' + str(plane) + '.tiff')
